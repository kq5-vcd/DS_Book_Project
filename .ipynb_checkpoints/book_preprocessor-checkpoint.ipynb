# %%
import pandas as pd

# %%
data = pd.read_csv('goodreads/books_1.csv')

data.head()
# Out:
#    BookID                                     Title  \
# 0       3     Harry Potter and the Sorcerer's Stone
# 1       1    Harry Potter and the Half-Blood Prince
# 2       7               The Harry Potter Collection
# 3      10                   Harry Potter Collection
# 4       5  Harry Potter and the Prisoner of Azkaban
#
#                         Author  Rating  Number of raters  5 stars  4 stars  \
# 0  J.K. Rowling, Mary GrandPré    4.48           7479780  4868903  1704361
# 1                 J.K. Rowling    4.57           2567345  1738165   611768
# 2  J.K. Rowling, Mary GrandPré    4.73             31236    25140     4473
# 3                 J.K. Rowling    4.73             31236    25140     4473
# 4  J.K. Rowling, Mary GrandPré    4.57           2993081  2028235   706012
#
#    3 stars  2 stars  1 star  Number of reviewers   Pages       PublishDate  \
# 0   631378   148016  127122               118557   309.0    June 26th 1997
# 1   175048    29134   13230                41832   652.0    July 16th 2005
# 2     1111      230     282                  921     NaN  January 1st 2005
# 3     1111      230     282                  921  3342.0  January 1st 2005
# 4   215277    29265   14292                58998   435.0     July 8th 1999
#
#              Book format Language               GenreLink        Series
# 0              Hardcover  English   /work/shelves/4640799  Harry Potter
# 1              Paperback  English  /work/shelves/41335427  Harry Potter
# 2              Paperback  English  /work/shelves/21457570  Harry Potter
# 3              Hardcover  English  /work/shelves/21457570  Harry Potter
# 4  Mass Market Paperback  English   /work/shelves/2402163  Harry Potter

# %%
len(data)
# Out:
# 96271

# %%
clean_v1 = data[~data.GenreLink.isnull()]

len(clean_v1)
# Out:
# 68571

# %%
clean_v2 = clean_v1.drop_duplicates(subset="BookID")
len(clean_v2)
# Out:
# 67476

# %%
clean_v2["Raters"] = clean_v2.loc[:, ("5 stars", "4 stars", "3 stars", "2 stars", "1 star")].apply(sum, axis=1)
clean_v2.head()
# Out:
# <ipython-input-6-118599e74fdf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_v2["Raters"] = clean_v2.loc[:, ("5 stars", "4 stars", "3 stars", "2 stars", "1 star")].apply(sum, axis=1)
#    BookID                                     Title  \
# 0       3     Harry Potter and the Sorcerer's Stone
# 1       1    Harry Potter and the Half-Blood Prince
# 2       7               The Harry Potter Collection
# 3      10                   Harry Potter Collection
# 4       5  Harry Potter and the Prisoner of Azkaban
#
#                         Author  Rating  Number of raters  5 stars  4 stars  \
# 0  J.K. Rowling, Mary GrandPré    4.48           7479780  4868903  1704361
# 1                 J.K. Rowling    4.57           2567345  1738165   611768
# 2  J.K. Rowling, Mary GrandPré    4.73             31236    25140     4473
# 3                 J.K. Rowling    4.73             31236    25140     4473
# 4  J.K. Rowling, Mary GrandPré    4.57           2993081  2028235   706012
#
#    3 stars  2 stars  1 star  Number of reviewers   Pages       PublishDate  \
# 0   631378   148016  127122               118557   309.0    June 26th 1997
# 1   175048    29134   13230                41832   652.0    July 16th 2005
# 2     1111      230     282                  921     NaN  January 1st 2005
# 3     1111      230     282                  921  3342.0  January 1st 2005
# 4   215277    29265   14292                58998   435.0     July 8th 1999
#
#              Book format Language               GenreLink        Series  \
# 0              Hardcover  English   /work/shelves/4640799  Harry Potter
# 1              Paperback  English  /work/shelves/41335427  Harry Potter
# 2              Paperback  English  /work/shelves/21457570  Harry Potter
# 3              Hardcover  English  /work/shelves/21457570  Harry Potter
# 4  Mass Market Paperback  English   /work/shelves/2402163  Harry Potter
#
#     Raters
# 0  7479780
# 1  2567345
# 2    31236
# 3    31236
# 4  2993081

# %%
clean_v3 = clean_v2[clean_v2["Raters"] > 150]
len(clean_v3)
# Out:
# 46561

# %%
clean_v3.GenreLink.str.split('/')
# Out:
# 0         [, work, shelves, 4640799]
# 1        [, work, shelves, 41335427]
# 2        [, work, shelves, 21457570]
# 3        [, work, shelves, 21457570]
# 4         [, work, shelves, 2402163]
#                     ...
# 96259       [, work, shelves, 96405]
# 96261       [, work, shelves, 96403]
# 96264       [, work, shelves, 96404]
# 96267       [, work, shelves, 96405]
# 96269       [, work, shelves, 31789]
# Name: GenreLink, Length: 46561, dtype: object
